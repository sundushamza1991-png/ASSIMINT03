# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# . P1rint Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
Name="hamza"
Fathername="zeeshan"
DOB="4/8/2000"

print (Name+"\t"+Fathername+"\t"+DOB)
# Out:
# hamza	zeeshan	4/8/2000

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
Name="hamza zeeshan"
Fathername="zeeshan"
DOb="4/8/2000"
city="Karachi"

print (Name)
print (Fathername)
print (DOb)
print (city)
# Out:
# hamza zeeshan
# zeeshan
# 4/8/2000
# Karachi

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
print(4+2)
print(82-50)
print(2*3)
print(8/2)
print(10%2)


print(7 > 4)
print(6<7)
print(8==8)
print(6<=9)
print(4>=8)
# Out:
# 6
# 32
# 6
# 4.0
# 0
# True
# True
# True
# True
# False

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
English=90
Islamiat=85
Maths=78

Total_marks=300

Obtained_marks = English+Islamiat+Maths

percentage=(Obtained_marks/Total_marks) * 100



print ("English marks:", English)
print ("Islamiat marks:", Islamiat)
print ("Maths marks:", Maths)
print ("Tottal marks:", Total_marks)
print ("Obtained Marks:", Obtained_marks)
print ("percentage:",percentage)
# Out:
# English marks: 90
# Islamiat marks: 85
# Maths marks: 78
# Tottal marks: 300
# Obtained Marks: 253
# percentage: 84.33333333333334
